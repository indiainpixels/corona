# %%
title = "https://www.imdb.com/title/tt0903747/episodes?season=1"

# %%
import requests
from bs4 import BeautifulSoup

# %%
data = requests.get(title)

# %%
soup = BeautifulSoup(data.text.strip())
#.find_all('span',{'class':'ipl-rating-star__rating'})

# %%
soup.find_all("div",{"class","list_item"})
# Out:
# [<div class="list_item odd">
#  <div class="image">
#  <a href="/title/tt1480055/" itemprop="url" title="Winter Is Coming"> <div class="hover-over-image zero-z-index" data-const="tt1480055">
#  <img alt="Winter Is Coming" class="zero-z-index" height="126" src="https://m.media-amazon.com/images/M/MV5BMTQ2NDIzNjEzOV5BMl5BanBnXkFtZTcwOTU2ODg5NA@@._V1_UX224_CR0,0,224,126_AL_.jpg" width="224"/>
#  <div>S1, Ep1</div>
#  </div>
#  </a> </div>
#  <div class="info" itemprop="episodes" itemscope="" itemtype="http://schema.org/TVEpisode">
#  <meta content="1" itemprop="episodeNumber"/>
#  <div class="airdate">
#              22 Aug. 2011
#      </div>
#  <strong><a href="/title/tt1480055/" itemprop="name" title="Winter Is Coming">Winter Is Coming</a></strong>
#  <div class="ipl-rating-widget">
#  <div class="ipl-rating-star small">
#  <span class="ipl-rating-star__star">
# ...

# %%
for div in soup.find_all("div",{"class","list_item"}):
    name = div.find("a")
    sc = div.find("span",{"class","ipl-rating-star__rating"})
    print(name["title"], sc.text)
# Out:
# Winter Is Coming 9.1
# The Kingsroad 8.8
# Lord Snow 8.7
# Cripples, Bastards, and Broken Things 8.8
# The Wolf and the Lion 9.1
# A Golden Crown 9.2
# You Win or You Die 9.2
# The Pointy End 9.0
# Baelor 9.6
# Fire and Blood 9.5

# %%
def ffy(yr):
    title = "https://www.imdb.com/title/tt2467372/episodes?season="+yr
    data = requests.get(title)
    soup = BeautifulSoup(data.text.strip())
    voo = []
    for div in soup.find_all("div",{"class","list_item"}):
        name = div.find("a")
        sc = div.find("span",{"class","ipl-rating-star__rating"})
        print(sc)
        voo.append({"name":name["title"], "score":sc.text})
    return voo

# %%
toRet = []
for y in range(1,9):
    toRet.append(ffy(str(y)))
# Out:
# <span class="ipl-rating-star__rating">7.8</span>
# <span class="ipl-rating-star__rating">7.6</span>
# <span class="ipl-rating-star__rating">7.6</span>
# <span class="ipl-rating-star__rating">7.8</span>
# <span class="ipl-rating-star__rating">8.0</span>
# <span class="ipl-rating-star__rating">8.5</span>
# <span class="ipl-rating-star__rating">8.1</span>
# <span class="ipl-rating-star__rating">7.8</span>
# <span class="ipl-rating-star__rating">7.7</span>
# <span class="ipl-rating-star__rating">8.3</span>
# <span class="ipl-rating-star__rating">8.2</span>
# <span class="ipl-rating-star__rating">8.2</span>
# <span class="ipl-rating-star__rating">8.8</span>
# <span class="ipl-rating-star__rating">7.7</span>
# <span class="ipl-rating-star__rating">8.2</span>
# <span class="ipl-rating-star__rating">8.6</span>
# <span class="ipl-rating-star__rating">8.0</span>
# <span class="ipl-rating-star__rating">7.7</span>
# <span class="ipl-rating-star__rating">8.5</span>
# ...

# %%
toRet
# Out:
# [[{'name': 'Pilot', 'score': '7.8'},
#   {'name': 'The Tagger', 'score': '7.6'},
#   {'name': 'The Slump', 'score': '7.6'},
#   {'name': 'M.E. Time', 'score': '7.8'},
#   {'name': 'The Vulture', 'score': '8.0'},
#   {'name': 'Halloween', 'score': '8.5'},
#   {'name': '48 Hours', 'score': '8.1'},
#   {'name': 'Old School', 'score': '7.8'},
#   {'name': "Sal's Pizza", 'score': '7.7'},
#   {'name': 'Thanksgiving', 'score': '8.3'},
#   {'name': 'Christmas', 'score': '8.2'},
#   {'name': 'Pontiac Bandit', 'score': '8.2'},
#   {'name': 'The Bet', 'score': '8.8'},
#   {'name': 'The Ebony Falcon', 'score': '7.7'},
#   {'name': 'Operation: Broken Feather', 'score': '8.2'},
#   {'name': 'The Party', 'score': '8.6'},
#   {'name': 'Full Boyle', 'score': '8.0'},
#   {'name': 'The Apartment', 'score': '7.7'},
#   {'name': 'Tactical Village', 'score': '8.5'},
#   {'name': 'Fancy Brudgom', 'score': '7.7'},
#   {'name': 'Unsolvable', 'score': '8.2'},
# ...
